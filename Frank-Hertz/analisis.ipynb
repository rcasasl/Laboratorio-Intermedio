# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math as m
from linregres import linregress_w as linr
import sympy as sym
from scipy.stats import chi2

# %%
def unpack(file_path):

    x = []
    x_title = ""
    y = []
    y_title = ""

    with open(file_path, 'r', encoding='iso-8859-1') as file:
        for line in file:
            # Process each line here
            line = line.strip()
            if line == "":
                continue
            line = line.split()
            if ord(line[0][-1]) > 57:
                x_title += line[0] + " "
                y_title += line[1] + " "
                continue
            line[0] = line[0].replace(",", ".")
            line[1] = line[1].replace(",", ".")
            x.append(float(line[0]))
            y.append(float(line[1]))
    
    return x, x_title, y, y_title

# %%
file_path = "Actividad21-1"

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/actividad21-1.png")

# %%
file_path = "Actividad21-2"

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/actividad21-2.png")

# %%
file_path = "Actividad21-3"

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/actividad21-3.png")

# %%
file_path1 = "Actividad21-1"
file_path2 = "Actividad21-2" 
file_path3 = "Actividad21-3"

x1,x_title,y1,y_title = unpack(file_path1) 
x2,x_title,y2,y_title = unpack(file_path2) 
x3,x_title,y3,y_title = unpack(file_path3) 

plt.figure(figsize=(10, 6))
plt.plot(x1, y1,c="r")
plt.plot(x2, y2,c="b")
plt.plot(x3, y3,c="k")
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.title("Corriente contra Voltaje para T=180°C,$U_2$ = 1.5V y $U_H$ = 6.3V")
plt.grid(True)
plt.savefig("Gráficas sin análisis/Actividad21-todas.png")

# %%
file_path = "22temp165"

x,x_title,y,y_title = unpack(file_path) 
plt.figure(figsize=(10, 6))
plt.plot(x, y)

plt.scatter(34.45,39.04,c = "r")
plt.annotate("(34.45V,39.04nA)",(35,39.04))

plt.scatter(29.32,21.11,c = "r")
plt.annotate("(29.32V,21.11nA)",(30,21.11))

plt.scatter(24.22,11.64,c = "r")
plt.annotate("(24.22V,11.64nA)",(25,11.64))

plt.scatter(19.26,6.49,c = "r")
plt.annotate("(19.26V,6.49nA)",(20,6.49))

plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/22temp165.png")

# %%
x1 = np.array([34.45,29.32,24.22,19.26])
y1 = np.array([39.04,21.11,11.64,6.49])
dy = np.array([0.01]*len(x1))
lin_reg = linr(x1,y1,dy)


f= lambda x1: lin_reg.slope()*x1+lin_reg.intercept()

x_p= np.linspace(min(x1),max(x1),500)

plt.scatter(x1,y1,c="r")
plt.grid()
plt.errorbar(x1, y1, yerr= dy, linestyle="")

plt.plot(x_p,f(x_p),c="k",linestyle="--")

print(lin_reg.slope(),"$\pm$",lin_reg.err_slope(),"\n",lin_reg.intercept(),
      "$\pm$",lin_reg.err_intercept())
# Out:
# 2.117995930449596 $\pm$ 0.0008825734307515873
#  -37.21876588517979 $\pm$ 0.024186461115715353

# %%
file_path = "22temp175" 

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)

plt.scatter(34.28,30.78,c = "r")
plt.annotate("(34.28V,30.78nA)",(35,30.78))

plt.scatter(29.13,17.30,c = "r")
plt.annotate("(29.13V,17.30nA)",(30,17.30))

plt.scatter(24.02,9.95,c = "r")
plt.annotate("(24.02V,9.95nA)",(25,9.95))

plt.scatter(19.24,5.71,c = "r")
plt.annotate("(19.24V,5.71nA)",(20,5.71))

plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/22temp175.png")

# %%
x1 = np.array([39.16,34.06,29.01,23.95,19.24])
y1 = np.array([37.27,21.50,12.71,7.65,4.60])
dy = np.array([0.01]*len(x1))
lin_reg = linr(x1,y1,dy)


f= lambda x1: lin_reg.slope()*x1+lin_reg.intercept()

x_p= np.linspace(min(x1),max(x1),500)

plt.scatter(x1,y1,c="r")
plt.grid()
plt.errorbar(x1, y1, yerr= dy, linestyle="")

plt.plot(x_p,f(x_p),c="k",linestyle="--")

print(lin_reg.slope(),"$\pm$",lin_reg.err_slope(),"\n",lin_reg.intercept(),
      "$\pm$",lin_reg.err_intercept())
# Out:
# 1.5909113421970353 $\pm$ 0.0006330202861289687
#  -29.524065476458574 $\pm$ 0.018946138326476965

# %%
file_path = "22temp185" 

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)

plt.scatter(39.16,37.27,c = "r")
plt.annotate("(39.16V,37.27nA)",(40,37.27))

plt.scatter(34.06,21.50,c = "r")
plt.annotate("(34.06V,21.50nA)",(35,21.50))

plt.scatter(29.01,12.71,c = "r")
plt.annotate("(29.01V,12.71nA)",(30,12.71))

plt.scatter(23.95,7.65,c = "r")
plt.annotate("(23.95V,7.65nA)",(25,7.65))

plt.scatter(19.24,4.60,c = "r")
plt.annotate("(19.24V,4.60nA)",(20,4.60))

plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/22temp185.png")

# %%
x1 = np.array([34.28,29.13,24.02,19.24])
y1 = np.array([30.78,29.13,9.95,5.71])
dy = np.array([0.01]*len(x1))
lin_reg = linr(x1,y1,dy)


f= lambda x1: lin_reg.slope()*x1+lin_reg.intercept()

x_p= np.linspace(min(x1),max(x1),500)

plt.scatter(x1,y1,c="r")
plt.grid()
plt.errorbar(x1, y1, yerr= dy, linestyle="")

plt.plot(x_p,f(x_p),c="k",linestyle="--")

print(lin_reg.slope(),"$\pm$",lin_reg.err_slope(),"\n",lin_reg.intercept(),
      "$\pm$",lin_reg.err_intercept())
# Out:
# 1.8804160674596044 $\pm$ 0.0008901960850248472
#  -31.253495478979 $\pm$ 0.024260143425561972

# %%
file_path1 = "22temp165"
file_path2 = "22temp175" 
file_path3 = "22temp185"

x1,x_title,y1,y_title = unpack(file_path1) 
x2,x_title,y2,y_title = unpack(file_path2) 
x3,x_title,y3,y_title = unpack(file_path3) 

plt.figure(figsize=(10, 6))
plt.plot(x1, y1,c="r",label="T = 165°C")
plt.plot(x2, y2,c="b",label="T = 175°C")
plt.plot(x3, y3,c="k",label="T = 185°C")
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.legend()
plt.grid(True)
plt.savefig("Gráficas sin análisis/22todastemp.png")

# %%
file_path = "23_1V"

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/23_1V.png")

# %%
file_path = "23_1,5V"

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/23_1,5V.png")

# %%
file_path = "23_2V"

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/23_2V.png")

# %%
file_path1 = "23_1V"
file_path2 = "23_1,5V"
file_path3 = "23_2V"

x1,x_title,y1,y_title = unpack(file_path1) 
x2,x_title,y2,y_title = unpack(file_path2) 
x3,x_title,y3,y_title = unpack(file_path3) 

plt.figure(figsize=(10, 6))
plt.plot(x1, y1,c="r",label="U_2 = 1V")
plt.plot(x2, y2,c="b",label="U_2= 1,5V")
plt.plot(x3, y3,c="k",label="U_2 = 2V")
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.legend()
plt.grid(True)
plt.savefig("Gráficas sin análisis/23_1y1,5y2.png")

# %%
file_path = "26_Uh5,8"

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/26_Uh5,8.png")

# %%
file_path = "26_Uh6,3"

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/26_Uh6,3.png")

# %%
file_path = "26_Uh6,8"

x,x_title,y,y_title = unpack(file_path) 

plt.figure(figsize=(10, 6))
plt.plot(x, y)
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.grid(True)
plt.savefig("Gráficas sin análisis/26_Uh6,8.png")

# %%
file_path1 = "26_Uh5,8"
file_path2 = "26_Uh6,3"
file_path3 = "26_Uh6,8"

x1,x_title,y1,y_title = unpack(file_path1) 
x2,x_title,y2,y_title = unpack(file_path2) 
x3,x_title,y3,y_title = unpack(file_path3) 

plt.figure(figsize=(10, 6))
plt.plot(x1, y1,c="r",label="U_H = 5.8V")
plt.plot(x2, y2,c="b",label="U_H = 6.3V")
plt.plot(x3, y3,c="k",label="U_H = 6.8V")
plt.xlabel(x_title)
plt.ylabel(y_title)
plt.legend()
plt.grid(True)
plt.savefig("Gráficas sin análisis/26_Uh5,8y6,3y6,8.png")

# %%
y1 = np.array([4.96,5.1,5.13])#Distancia para 165°C
x1 = np.array([3,4,5])

y2 = np.array([4.71,5.06,5.05,5.1])#Distancia para 185°C
x2 = np.array([3,4,5,6])

y3 = np.array([4.78,5.11,5.15])#Distancia para 175°C
x3 = np.array([3,4,5])

dy1 = np.array([0.01]*len(x1))
dy2 = np.array([0.01]*len(x2))
dy3 = np.array([0.01]*len(x3))

lin_reg1 = linr(x1,y1,dy1)
lin_reg2 = linr(x2,y2,dy2)
lin_reg3 = linr(x3,y3,dy3)


f1 = lambda x1: lin_reg1.slope()*x1+lin_reg1.intercept()
f2 = lambda x2: lin_reg2.slope()*x2+lin_reg2.intercept()
f3 = lambda x3: lin_reg3.slope()*x3+lin_reg3.intercept()

x_p1= np.linspace(min(x1),max(x1),500)
x_p2= np.linspace(min(x2),max(x2),500)
x_p3= np.linspace(min(x3),max(x3),500)

plt.scatter(x1,y1,c="r")
plt.grid()
plt.errorbar(x1, y1, yerr= dy1, c="k", linestyle="")
plt.plot(x_p1,f1(x_p1),c="r",linestyle="solid", label="Ajuste lineal para T = 165°C")

plt.scatter(x2,y2,c="b")
plt.grid()
plt.errorbar(x2, y2, yerr= dy2, c="k", linestyle="")
plt.plot(x_p2,f2(x_p2),c="b",linestyle="solid", label="Ajuste lineal para T = 185°C")

plt.scatter(x3,y3,c="g")
plt.grid()
plt.errorbar(x3, y3, yerr= dy3, c="k", linestyle="")
plt.plot(x_p3,f3(x_p3),c="g",linestyle="solid", label="Ajuste lineal para T = 175°C")

plt.ylabel("Distancia entre mínimos (eV)")
plt.xlabel("Orden de los mínimos")
plt.title("Distancia entre mínimos contra Orden de los mínimos")
plt.legend()
plt.savefig("Gráficas sin análisis/analisis7.png")

print("Temperatura de 165°C:",lin_reg1.slope(),"$\pm$",lin_reg1.err_slope(),"\n",lin_reg1.intercept(),
      "$\pm$",lin_reg1.err_intercept())
print("Temperatura de 185°C:",lin_reg2.slope(),"$\pm$",lin_reg2.err_slope(),"\n",lin_reg2.intercept(),
      "$\pm$",lin_reg2.err_intercept())
print("Temperatura de 175°C:",lin_reg3.slope(),"$\pm$",lin_reg3.err_slope(),"\n",lin_reg3.intercept(),
      "$\pm$",lin_reg3.err_intercept())
# Out:
# Temperatura de 165°C: 0.085 $\pm$ 0.007071067811865475
#  4.723333333333334 $\pm$ 0.02886751345948129
# Temperatura de 185°C: 0.116 $\pm$ 0.00447213595499958
#  4.458 $\pm$ 0.02073644135332772
# Temperatura de 175°C: 0.185 $\pm$ 0.007071067811865475
#  4.273333333333333 $\pm$ 0.02886751345948129
